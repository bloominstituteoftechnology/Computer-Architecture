# %%
data = """
51.15
50.96
54.54
55.28
54.27
52.75
51.83
53.4
53.78
56.28
57.86
60.92
63.71
63.84
65.2
65.9
67.08
65.61
64.98
63.08
62.59
59.94
58.57
55.59
56.69
55.69
54.44
53.09
52.06
51.01
50.54
54.92
55.75
58.09
60.87
62.52
63.54
59.16
59.48
58.34
57.19
58.6
59.48
62.23
61.6
59.59
59.54
58.96
59.12
56.9
53.62
54.15
53.64
53.45
52.67
53.81
55.28
57.08
59.09
58.92
58.45
59.18
59.24
58.75
57.5
57.41
56.76
55.16
52.45
51.95
50.91
50.07
50.1
50.15
50.4
50.17
50.14
50.35
50.7
53.89
55.61
57.22
57.63
59.05
59.53
60.19
61.73
61.94
62.38
61.92
61.29
59.54
57.34
55.91
54.05
52.58
51.12
49.73
48.97
48.06
47.51
46.81
46.56
49.3
53.37
55.31
57.57
59.41
60.81
61.01
59.8
60.05
59.68
59.41
60.05
59.11
54.68
52.72
51.39
50.52
50.74
50.12
49.09
48.18
47.14
46.94
47.56
50.15
52.25
55.55
57.55
60.48
61.9
63.7
64.34
65.36
60.82
58.99
61.4
61.34
59.82
57.67
56.25
56.27
54.64
53.71
52.45
52.04
51.8
50.89
49.62
50.21
53.11
57.37
57.41
57.96
57.87
58.37
58.56
58.28
60.99
56.44
55.85
56.6
57.74
58.04
59.72
58.9
56.96
"""

# %%
str_data = data.strip().split('\n')
nums = [float(i) for i in str_data]
nums = nums[:-1]
len(nums)
# Out:
# 168

# %%
days = []
for hour in range(0, len(nums), 24):
    days.append(nums[hour:hour+24])

# %%
import numpy as np
preds = np.mean(days, axis=0)

# %%
answer = list(preds)
answer.extend(answer)

# %%
len(answer)
# Out:
# 48

# %%
sum(test)/len(test)
# Out:
# 32.967083333333335

# %%
test[1] - avg + test[1]
# Out:
# 35.752916666666664

# %%
def predictTemperature(temperature, n):
    days = []
    for hour in range(0, len(temperature), 24):
        days.append(temperature[hour:hour+24])
    average_day = np.mean(days, axis=0)
    predictions = []
    for _ in range(n//24):
        predictions.extend(average_day)
    return predictions

# %%
predictTemperature(nums,100)
# Out:
# [53.36571428571428,
#  52.465714285714284,
#  51.93000000000001,
#  51.56714285714286,
#  50.93714285714286,
#  50.3142857142857,
#  49.925714285714285,
#  52.239999999999995,
#  54.16428571428572,
#  56.7,
#  58.28285714285715,
#  59.89428571428572,
#  60.82999999999999,
#  60.778571428571425,
#  61.192857142857136,
#  61.23142857142857,
#  60.80571428571428,
#  59.768571428571434,
#  59.972857142857144,
#  59.580000000000005,
#  58.03142857142857,
#  56.54571428571429,
#  55.77571428571428,
#  54.69857142857142,
#  53.36571428571428,
#  52.465714285714284,
#  51.93000000000001,
#  51.56714285714286,
#  50.93714285714286,
#  50.3142857142857,
#  49.925714285714285,
#  52.239999999999995,
#  54.16428571428572,
#  56.7,
#  58.28285714285715,
#  59.89428571428572,
#  60.82999999999999,
#  60.778571428571425,
#  61.192857142857136,
#  61.23142857142857,
#  60.80571428571428,
#  59.768571428571434,
#  59.972857142857144,
#  59.580000000000005,
#  58.03142857142857,
#  56.54571428571429,
# ...

# %%
import math
math.mean(nums)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-89e0e4f29655> in <module>
#       1 import math
# ----> 2 math.mean(nums)
#
# AttributeError: module 'math' has no attribute 'mean'
